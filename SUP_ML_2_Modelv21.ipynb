# %% [markdown]
# <a href="https://colab.research.google.com/github/rulogar1234/nuclio-1/blob/develop/SUP_ML_2_Modelv21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SUP ML 2 - MODEL

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from sklearn import set_config

pd.set_option('display.max_columns',None)

import warnings
warnings.filterwarnings("ignore")

# %%
import os
if sklearn.__version__ != "1.2.2":
    os.system("pip install scikit-learn==1.2.2")
print("Versión de scikit-learn:", sklearn.__version__)
# Out:
# Versión de scikit-learn: 1.2.2

# %% [markdown]
# # Carga clean data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fichero_pickle_='/content/drive/MyDrive/Colab Notebooks/TEMPLATE SUP ML (main)/EJERCICIO-ML-SUP/data/churn_processed_train_data.pkl'
import pickle
df_t= pd.read_pickle(fichero_pickle_)

# %%
df_t.shape
# Out:
# (89999, 77)

# %%
#para que las salidas sean dataframes
set_config(transform_output = "pandas")

# %% [markdown]
# # Split X-y

# %%
#definimos el target
target = df_t.filter(like='churn').columns.tolist()[0]
features = df_t.columns[df_t.columns!=target]

# Divide dataset en matriz de variables (X) y output (y)
X = df_t[features]
y = df_t[target]

# %% [markdown]
# # Distribución del target

# %%
sns.countplot(data=df_t,x=target)
plt.title('Target distribution')
plt.plot()
# Out:
# []

# %% [markdown]
# # Undersampling (*)

# %% [markdown]
# **NOTA:** SOLO EN CLASIFICACIÓN cuando el ratio de éxitos está MUY DESBALANCEADO (<10%).

# %%
#Vamos a mirar de el train cuantos positivos y negativos  hay respecto a la muestra total
positivos=df_t[df_t[target]==1]
negativos=df_t[df_t[target]==0]

# %%
#El ratio de éxitos es prácticamente igual al de fracasos (3% de diferencia), la muestra está balanceada, no hace fata hacer undersampling
(len(positivos)/len(negativos)-1)*100
# Out:
# 3.6222538971469875

# %% [markdown]
# # Split TRAIN-TEST

# %%
test_rate = 0.2
total_rows = len(y)
test_size = int(test_rate*total_rows)
train_size = total_rows - test_size

print('TRAIN-VALIDA: %d (%.1f%%)' %(train_size,(100-test_rate*100)))
print('TEST: %d (%.1f%%)' %(test_size,(test_rate*100)))
# Out:
# TRAIN-VALIDA: 72000 (80.0%)
# TEST: 17999 (20.0%)

# %%
#Como so sabemos si el dataset está ordenado de manera aleatoria, le damos un "meneo" y volvemos a dividir la matriz,
# creamos un dataset más pequeño para probar los arboles de decisión que tarden más
df_t2 = df_t.sample(frac=1, random_state=42)

# Divide dataset en matriz de variables (X) y output (y)
X = df_t2[features]
y = df_t2[target]

# %%
X.head(3)
# Out:
#              hnd_web_cap__hnd_webcap__col_mas__hnd_webcap_UNKW  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              hnd_web_cap__hnd_webcap__col_mas__hnd_webcap_WC  \
# Customer_ID
# 1054760                                                    0
# 1012457                                                    1
# 1053402                                                    0
#
#              hnd_web_cap__hnd_webcap__col_mas__hnd_webcap_WCMB  \
# Customer_ID
# 1054760                                                      1
# 1012457                                                      0
# 1053402                                                      1
#
#              prizm_social_one__prizm_social_one__col_1__prizm_social_one_C  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              prizm_social_one__prizm_social_one__col_1__prizm_social_one_R  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              prizm_social_one__prizm_social_one__col_1__prizm_social_one_S  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      1
#
#              prizm_social_one__prizm_social_one__col_1__prizm_social_one_T  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      1
# 1053402                                                      0
#
#              prizm_social_one__prizm_social_one__col_1__prizm_social_one_U  \
# Customer_ID
# 1054760                                                      1
# 1012457                                                      0
# 1053402                                                      0
#
#              marital__marital__col_1__marital_A  \
# Customer_ID
# 1054760                                       0
# 1012457                                       0
# 1053402                                       0
#
#              marital__marital__col_1__marital_B  \
# Customer_ID
# 1054760                                       0
# 1012457                                       0
# 1053402                                       1
#
#              marital__marital__col_1__marital_M  \
# Customer_ID
# 1054760                                       0
# 1012457                                       1
# 1053402                                       0
#
#              marital__marital__col_1__marital_S  \
# Customer_ID
# 1054760                                       0
# 1012457                                       0
# 1053402                                       0
#
#              marital__marital__col_1__marital_U  \
# Customer_ID
# 1054760                                       1
# 1012457                                       0
# 1053402                                       0
#
#              remainder__crclscod__remainder__crclscod  \
# Customer_ID
# 1054760                                             3
# 1012457                                             0
# 1053402                                            10
#
#              remainder__asl_flag__remainder__asl_flag  \
# Customer_ID
# 1054760                                             0
# 1012457                                             0
# 1053402                                             0
#
#              remainder__refurb_new__remainder__refurb_new  \
# Customer_ID
# 1054760                                                 0
# 1012457                                                 0
# 1053402                                                 1
#
#              remainder__area__col_mas__area_ATLANTIC SOUTH AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_CALIFORNIA NORTH AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_CENTRAL/SOUTH TEXAS AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_CHICAGO AREA  \
# Customer_ID
# 1054760                                                0
# 1012457                                                0
# 1053402                                                0
#
#              remainder__area__col_mas__area_DALLAS AREA  \
# Customer_ID
# 1054760                                               0
# 1012457                                               0
# 1053402                                               1
#
#              remainder__area__col_mas__area_DC/MARYLAND/VIRGINIA AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_GREAT LAKES AREA  \
# Customer_ID
# 1054760                                                    1
# 1012457                                                    0
# 1053402                                                    0
#
#              remainder__area__col_mas__area_HOUSTON AREA  \
# Customer_ID
# 1054760                                                0
# 1012457                                                0
# 1053402                                                0
#
#              remainder__area__col_mas__area_LOS ANGELES AREA  \
# Customer_ID
# 1054760                                                    0
# 1012457                                                    0
# 1053402                                                    0
#
#              remainder__area__col_mas__area_MIDWEST AREA  \
# Customer_ID
# 1054760                                                0
# 1012457                                                0
# 1053402                                                0
#
#              remainder__area__col_mas__area_NEW ENGLAND AREA  \
# Customer_ID
# 1054760                                                    0
# 1012457                                                    0
# 1053402                                                    0
#
#              remainder__area__col_mas__area_NEW YORK CITY AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_NORTH FLORIDA AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_NORTHWEST/ROCKY MOUNTAIN AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_OHIO AREA  \
# Customer_ID
# 1054760                                             0
# 1012457                                             0
# 1053402                                             0
#
#              remainder__area__col_mas__area_PHILADELPHIA AREA  \
# Customer_ID
# 1054760                                                     0
# 1012457                                                     0
# 1053402                                                     0
#
#              remainder__area__col_mas__area_SOUTH FLORIDA AREA  \
# Customer_ID
# 1054760                                                      0
# 1012457                                                      0
# 1053402                                                      0
#
#              remainder__area__col_mas__area_SOUTHWEST AREA  \
# Customer_ID
# 1054760                                                  0
# 1012457                                                  0
# 1053402                                                  0
#
#              remainder__area__col_mas__area_TENNESSEE AREA  \
# Customer_ID
# 1054760                                                  0
# 1012457                                                  1
# 1053402                                                  0
#
#              remainder__new_cell__remainder__new_cell_N  \
# Customer_ID
# 1054760                                               0
# 1012457                                               1
# 1053402                                               0
#
#              remainder__new_cell__remainder__new_cell_U  \
# Customer_ID
# 1054760                                               1
# 1012457                                               0
# 1053402                                               1
#
#              remainder__new_cell__remainder__new_cell_Y  \
# Customer_ID
# 1054760                                               0
# 1012457                                               0
# 1053402                                               0
#
#              remainder__creditcd__col_1__creditcd_-U  \
# Customer_ID
# 1054760                                            0
# 1012457                                            0
# 1053402                                            0
#
#              remainder__creditcd__col_1__creditcd_N  \
# Customer_ID
# 1054760                                           1
# 1012457                                           0
# 1053402                                           1
#
#              remainder__remainder__col_num__change_mou  \
# Customer_ID
# 1054760                                         -50.75
# 1012457                                         317.50
# 1053402                                         206.75
#
#              remainder__remainder__col_num__mou  \
# Customer_ID
# 1054760                                  181.75
# 1012457                                  376.50
# 1053402                                 2121.25
#
#              remainder__remainder__col_num__hnd_price  \
# Customer_ID
# 1054760                                      79.98999
# 1012457                                      29.98999
# 1053402                                      99.98999
#
#              remainder__remainder__income__income  \
# Customer_ID
# 1054760                                  -3875000
# 1012457                                         9
# 1053402                                         4
#
#              remainder__remainder__eqpdays__eqpdays  \
# Customer_ID
# 1054760                                         520
# 1012457                                         186
# 1053402                                          77
#
#              remainder__remainder__remainder__months  \
# Customer_ID
# 1054760                                           18
# 1012457                                           28
# 1053402                                           14
#
#              remainder__remainder__remainder__drop_vce  \
# Customer_ID
# 1054760                                       0.000000
# 1012457                                       2.333333
# 1053402                                       0.000000
#
#              remainder__remainder__remainder__avgqty  \
# Customer_ID
# 1054760                                        85.06
# 1012457                                        96.04
# 1053402                                       788.62
#
#              remainder__remainder__remainder__uniqsubs  \
# Customer_ID
# 1054760                                              4
# 1012457                                              2
# 1053402                                              1
#
#              remainder__remainder__remainder__mou_cvce  \
# Customer_ID
# 1054760                                       0.000000
# 1012457                                     145.586667
# 1053402                                       0.000000
#
#              remainder__remainder__remainder__avg3mou  \
# Customer_ID
# 1054760                                           199
# 1012457                                           271
# 1053402                                          2052
#
#              remainder__remainder__remainder__avgmou  \
# Customer_ID
# 1054760                                       200.19
# 1012457                                       191.22
# 1053402                                      2044.69
#
#              remainder__remainder__remainder__adjrev  \
# Customer_ID
# 1054760                                      1054.37
# 1012457                                       887.79
# 1053402                                      2109.94
#
#              remainder__remainder__remainder__owylis_vce  \
# Customer_ID
# 1054760                                         0.000000
# 1012457                                         6.666667
# 1053402                                         0.000000
#
#              remainder__remainder__remainder__recv_vce  \
# Customer_ID
# 1054760                                       0.000000
# 1012457                                      46.666667
# 1053402                                       0.000000
#
#              remainder__remainder__remainder__avg3rev  \
# Customer_ID
# 1054760                                            62
# 1012457                                            34
# 1053402                                           171
#
#              remainder__remainder__remainder__mouiwylisv  \
# Customer_ID
# 1054760                                         0.000000
# 1012457                                         7.083333
# 1053402                                         0.000000
#
#              remainder__remainder__remainder__adjqty  \
# Customer_ID
# 1054760                                         1361
# 1012457                                         2593
# 1053402                                        10252
#
#              remainder__remainder__remainder__drop_blk  \
# Customer_ID
# 1054760                                       0.000000
# 1012457                                      14.333333
# 1053402                                       0.000000
#
#              remainder__remainder__remainder__avgrev  \
# Customer_ID
# 1054760                                        65.90
# 1012457                                        32.88
# 1053402                                       162.30
#
#              remainder__remainder__remainder__mou_opkv  \
# Customer_ID
# 1054760                                           0.00
# 1012457                                          32.68
# 1053402                                           0.00
#
#              remainder__remainder__remainder__avg3qty  \
# Customer_ID
# 1054760                                            87
# 1012457                                           137
# 1053402                                           790
#
#              remainder__remainder__remainder__mou_peav  \
# Customer_ID
# 1054760                                       0.000000
# 1012457                                     204.276667
# 1053402                                       0.000000
#
#              remainder__remainder__remainder__phones  \
# Customer_ID
# 1054760                                            1
# 1012457                                            2
# 1053402                                            3
#
#              remainder__remainder__remainder__complete  \
# Customer_ID
# 1054760                                            0.0
# 1012457                                           91.0
# 1053402                                            0.0
#
#              remainder__remainder__remainder__opk_vce  \
# Customer_ID
# 1054760                                      0.000000
# 1012457                                     19.666667
# 1053402                                      0.000000
#
#              remainder__remainder__remainder__adjmou  \
# Customer_ID
# 1054760                                       3203.0
# 1012457                                       5163.0
# 1053402                                      26581.0
#
#              remainder__remainder__remainder__actvsubs  \
# Customer_ID
# 1054760                                              2
# 1012457                                              2
# 1053402                                              1
#
#              remainder__remainder__remainder__custcare  \
# Customer_ID
# 1054760                                            0.0
# 1012457                                            1.0
# 1053402                                            0.0
#
#              remainder__remainder__remainder__unan_vce  \
# Customer_ID
# 1054760                                       0.000000
# 1012457                                      13.333333
# 1053402                                       0.000000
#
#              remainder__remainder__remainder__mou_rvce  \
# Customer_ID
# 1054760                                           0.00
# 1012457                                          91.37
# 1053402                                           0.00
#
#              remainder__remainder__remainder__threeway  \
# Customer_ID
# 1054760                                       0.000000
# 1012457                                       0.333333
# 1053402                                       0.000000
#
#              remainder__remainder__remainder__blck_vce  \
# Customer_ID
# 1054760                                            0.0
# 1012457                                           12.0
# 1053402                                            0.0
#
#              remainder__remainder__remainder__mouowylisv  \
# Customer_ID
# 1054760                                         0.000000
# 1012457                                         1.976667
# 1053402                                         0.000000
#
#              remainder__remainder__remainder__ccrndmou  \
# Customer_ID
# 1054760                                            0.0
# 1012457                                           10.0
# 1053402                                            0.0
#
#              remainder__remainder__remainder__callwait
# Customer_ID
# 1054760                                       0.000000
# 1012457                                       0.333333
# 1053402                                       0.000000

# %%
y.head(3)
# Out:
# Customer_ID
# 1054760    1
# 1012457    1
# 1053402    1
# Name: remainder__remainder__remainder__churn, dtype: int64

# %%
#dividimos
X_train = X.head(train_size)
y_train = y.head(train_size)
X_test = X.tail(test_size)
y_test = y.tail(test_size)

# %% [markdown]
# # Rescaling

# %% [markdown]
# * NO NECESARIO en modelos de Arboles de Decisión.
# * Guardar scaler en el model path.

# %%
from sklearn.preprocessing import StandardScaler
# Estandarización: fit_transform() en train, transform() en test, estandard scaling se usa cuando los datos no sean tan sensibles a outlayers
scaler = StandardScaler()

X_train_std = scaler.fit_transform(X_train)

X_train_std = pd.DataFrame(X_train_std, columns = X_train.columns, index= X_train.index)

# %% [markdown]
# # TRAIN-VALIDA

# %% [markdown]
# ## Torneo de Modelos

# %% [markdown]
# * Probamos una colección de modelos con el objetivo de conseguir el mejor rendimiento del modelo en los datos de VALIDACION.

# %%
import sklearn
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Funcion que calcula el AUC de un modelo sobre un dataset (X-y). Args: modelo a validar, X, y
def auc(model,X,y):
  model.fit(X,y)
  return roc_auc_score(y,model.predict_proba(X)[:,1])

# Funcion que calcula el AUC en Cross-Validation (X-y). Args: modelo a validar, X, y
def auc_cross_validation(model,X,y):
  cross_val = cross_val_score(model,
                              X, y,
                              cv=4,                 # Numero de folds que vamos a utilizar para validar
                              scoring='roc_auc'     # La metrica de validacion que se medira en cada train-valida
                              )
  return cross_val.mean()

# %%
# Inicializa resultados
label_, auc_train_ , auc_valida_ = [], [], []

# Completa un registro en dataframe con los resultados de las funciones definidas previsamente ( AUC y AUC con cross-validation)

# Inputs:
#   * modelo
#   * (X,y)
#   * label especifico si queremos registrar el resultado con otro nombre (opcional)


def evaluate_classification(model, X, y, label=None):
  if label is None:
    label=str(model)
  label_.append(label)

  auc_train = auc(model,X,y)
  auc_valida = auc_cross_validation(model,X,y)
  auc_train_.append(auc_train)
  auc_valida_.append(auc_valida)

  return pd.DataFrame({'Model': label_,
                      'AUC Train': auc_train_,
                      'AUC Cross-Valida': auc_valida_
                      }).sort_values('AUC Cross-Valida',ascending=False)

# %%
#Vamos a hacer una primera barrida de modelos con una muestra más pequeña para orientarnos en los más eficientes sin tener que esperar tanto, primero lo hacemos con datos de entrenamiento estadarizado
X_train_std_s=X_train_std.head(5000)
X_train_s=X_train.head(5000)
y_train_s=y_train.head(5000)

# %%
'''modelos=[DecisionTreeClassifier(),RandomForestClassifier(),XGBClassifier(),LGBMClassifier(),KNeighborsClassifier(),GradientBoostingClassifier(),MLPClassifier(),ExtraTreesClassifier()]
label_.clear()
auc_train_.clear()
auc_valida_.clear()
for i in modelos:
  model=i
  model.fit(X_train_std_s, y_train_s)
  modelcomp=evaluate_classification(model, X_train_std_s,y_train_s)
modelcomp'''
# Out:
# 'modelos=[DecisionTreeClassifier(),RandomForestClassifier(),XGBClassifier(),LGBMClassifier(),KNeighborsClassifier(),GradientBoostingClassifier(),MLPClassifier(),ExtraTreesClassifier()]\nlabel_.clear()\nauc_train_.clear()\nauc_valida_.clear()\nfor i in modelos:\n  model=i\n  model.fit(X_train_std_s, y_train_s)\n  modelcomp=evaluate_classification(model, X_train_std_s,y_train_s)\nmodelcomp'

# %%
#después sin los datos estandarizados
'''modelos=[DecisionTreeClassifier(),RandomForestClassifier(),XGBClassifier(),LGBMClassifier(),KNeighborsClassifier(),GradientBoostingClassifier(),MLPClassifier(),ExtraTreesClassifier()]
label_.clear()
auc_train_.clear()
auc_valida_.clear()
for i in modelos:
  model=i
  model.fit(X_train_s, y_train_s)
  modelcomp=evaluate_classification(model, X_train_s,y_train_s)
modelcomp'''
# Out:
# 'modelos=[DecisionTreeClassifier(),RandomForestClassifier(),XGBClassifier(),LGBMClassifier(),KNeighborsClassifier(),GradientBoostingClassifier(),MLPClassifier(),ExtraTreesClassifier()]\nlabel_.clear()\nauc_train_.clear()\nauc_valida_.clear()\nfor i in modelos:\n  model=i\n  model.fit(X_train_s, y_train_s)\n  modelcomp=evaluate_classification(model, X_train_s,y_train_s)\nmodelcomp'

# %%
#Cogemos los 2 primeros modelos y le pasamos los datos de entrenamiento completos
'''modelos=[GradientBoostingClassifier(),RandomForestClassifier()]
label_.clear()
auc_train_.clear()
auc_valida_.clear()
for i in modelos:
  model=i
  model.fit(X_train_std, y_train)
  modelcomp=evaluate_classification(model, X_train_std, y_train)
modelcomp'''
# Out:
# 'modelos=[GradientBoostingClassifier(),RandomForestClassifier()]\nlabel_.clear()\nauc_train_.clear()\nauc_valida_.clear()\nfor i in modelos:\n  model=i\n  model.fit(X_train_std, y_train)\n  modelcomp=evaluate_classification(model, X_train_std, y_train)\nmodelcomp'

# %%
#Cogemos los 2 primeros modelos y le pasamos los datos de entrenamiento que han dado mejor puntuación en el paso anterior
'''modelos=[RandomForestClassifier(),GradientBoostingClassifier()]
label_.clear()
auc_train_.clear()
auc_valida_.clear()
for i in modelos:
  model=i
  model.fit(X_train, y_train)
  modelcomp=evaluate_classification(model, X_train,y_train)
modelcomp'''
# Out:
# 'modelos=[RandomForestClassifier(),GradientBoostingClassifier()]\nlabel_.clear()\nauc_train_.clear()\nauc_valida_.clear()\nfor i in modelos:\n  model=i\n  model.fit(X_train, y_train)\n  modelcomp=evaluate_classification(model, X_train,y_train)\nmodelcomp'

# %% [markdown]
# ## Hiperparametrizacion

# %% [markdown]
# * Utilizar RandomSearch para probar diferentes configuraciones de los parametros del modelo ganador en el torneo de modelos con el objetivo de mejorar el control del overfitting.

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
'''param_distributions = {
    'learning_rate': [0.03],  # Tasas de aprendizaje sugeridas
    'max_depth': [7],  # Profundidades máximas sugeridas
    'n_estimators': [600],  # Número de árboles sugeridos
    'subsample': [0.8],  # Fracción de muestras para entrenar cada árbol
    'min_samples_split': [20, 25, 30, 40, 50],  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [10, 15, 20],  # Número mínimo de muestras requeridas para ser una hoja
    'max_features': ['sqrt']  # Número de características a considerar para la mejor división
}'''
# Out:
# "param_distributions = {\n    'learning_rate': [0.03],  # Tasas de aprendizaje sugeridas\n    'max_depth': [7],  # Profundidades máximas sugeridas\n    'n_estimators': [600],  # Número de árboles sugeridos\n    'subsample': [0.8],  # Fracción de muestras para entrenar cada árbol\n    'min_samples_split': [20, 25, 30, 40, 50],  # Número mínimo de muestras requeridas para dividir un nodo interno\n    'min_samples_leaf': [10, 15, 20],  # Número mínimo de muestras requeridas para ser una hoja\n    'max_features': ['sqrt']  # Número de características a considerar para la mejor división\n}"

# %%
param_distributions = {
    'learning_rate': [0.03, 0.04],
    'max_depth': [5],  # Profundidades máximas sugeridas
    'n_estimators': [200],  # Número de árboles sugeridos
    'subsample': [0.9],  # Fracción de muestras para entrenar cada árbol
    'min_samples_split': [30],  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [10],  # Número mínimo de muestras requeridas para ser una hoja
    'max_features': ['sqrt', 'log2', 'auto']  # Número de características a considerar para la mejor división
}

# %%
#parametros con model
'''param_distributions = {
    'learning_rate': [0.04],  # Tasas de aprendizaje sugeridas
    'max_depth': [9],  # Profundidades máximas sugeridas
    'n_estimators': [250],  # Número de árboles sugeridos
    'subsample': [0.9],  # Fracción de muestras para entrenar cada árbol
    'min_samples_split': [1],  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [15],  # Número mínimo de muestras requeridas para ser una hoja
    'max_features': ['sqrt']  # Número de características a considerar para la mejor división
}'''
# Out:
# "param_distributions = {\n    'learning_rate': [0.04],  # Tasas de aprendizaje sugeridas\n    'max_depth': [9],  # Profundidades máximas sugeridas\n    'n_estimators': [250],  # Número de árboles sugeridos\n    'subsample': [0.9],  # Fracción de muestras para entrenar cada árbol\n    'min_samples_split': [1],  # Número mínimo de muestras requeridas para dividir un nodo interno\n    'min_samples_leaf': [15],  # Número mínimo de muestras requeridas para ser una hoja\n    'max_features': ['sqrt']  # Número de características a considerar para la mejor división\n}"

# %%
#Esta es la clase que se utiliza para realizar una búsqueda aleatoria de hiperparámetros mediante validación cruzada.
'''random_search = RandomizedSearchCV(estimator=LGBMClassifier(random_state=42),
                                   param_distributions=param_distributions,
                                   n_iter=50, #Especifica el número de iteraciones de búsqueda aleatoria que se realizarán. En este caso, se realizarán 10 iteraciones.
                                   cv=5, #Especifica el esquema de validación cruzada que se utilizará durante la búsqueda. En este caso, se está utilizando una validación cruzada de 5-fold (5-folds cross-validation).
                                   scoring='roc_auc',
                                   random_state=42 #Este parámetro se utiliza para fijar la semilla aleatoria y garantizar la reproducibilidad de los resultados. En este caso, se está utilizando el valor 42 como semilla aleatoria.
                                   )'''
# Out:
# "random_search = RandomizedSearchCV(estimator=LGBMClassifier(random_state=42),\n                                   param_distributions=param_distributions,\n                                   n_iter=50, #Especifica el número de iteraciones de búsqueda aleatoria que se realizarán. En este caso, se realizarán 10 iteraciones.\n                                   cv=5, #Especifica el esquema de validación cruzada que se utilizará durante la búsqueda. En este caso, se está utilizando una validación cruzada de 5-fold (5-folds cross-validation).\n                                   scoring='roc_auc',\n                                   random_state=42 #Este parámetro se utiliza para fijar la semilla aleatoria y garantizar la reproducibilidad de los resultados. En este caso, se está utilizando el valor 42 como semilla aleatoria.\n                                   )"

# %%
# Configuración de RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=GradientBoostingClassifier(random_state=42),  # Estimador GradientBoostingClassifier
    param_distributions=param_distributions,
    scoring='roc_auc',  # Métrica a optimizar: AUC
    cv=5,  # Número de folds para cross-validation
    n_iter=20
    #, # Número de iteraciones, cada una testeará una configuración distinta
    #n_jobs=-1,  # Utilizar todos los procesadores disponibles
    #verbose=True
)

# %%
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingClassifier(random_state=42),
#                    n_iter=20,
#                    param_distributions={'learning_rate': [0.03, 0.04],
#                                         'max_depth': [5],
#                                         'max_features': ['sqrt', 'log2',
#                                                          'auto'],
#                                         'min_samples_leaf': [10],
#                                         'min_samples_split': [30],
#                                         'n_estimators': [200],
#                                         'subsample': [0.9]},
#                    scoring='roc_auc')

# %%
random_search.best_estimator_
# Out:
# GradientBoostingClassifier(learning_rate=0.04, max_depth=5, max_features='auto',
#                            min_samples_leaf=10, min_samples_split=30,
#                            n_estimators=200, random_state=42, subsample=0.9)

# %%
random_search.best_score_
# Out:
# 0.6714709426717194

# %% [markdown]
# ## Modelo final

# %% [markdown]
# * Entrenar el modelo final con el algoritmo y los parametros que hanfuncionado mejor en anteriores experimentos.
# * Argumentar la elección.
# * Guardar el modelo en model path.

# %%
best_model = random_search.best_estimator_

# %% [markdown]
# # TEST

# %% [markdown]
# * Evaluación de las métricas de performance en TEST.

# %%
y_train_pred = best_model.predict(X_train)              # predicciones del modelo en los datos de TRAIN
y_test_pred = best_model.predict(X_test)                # predicciones del modelo en los datos de TEST

# %%
y_train_pred_proba = best_model.predict_proba(X_train)[:, 1]      # probabilidad de éxito (1) segun el modelo en los datos de TRAIN
y_test_pred_proba = best_model.predict_proba(X_test)[:, 1]        # probabilidad de éxito (1) segun el modelo en los datos de TEST

# %% [markdown]
# # AUC

# %%
from sklearn.metrics import roc_auc_score

# %%
auc_train = roc_auc_score(y_train, y_train_pred_proba)      # AUC en TRAIN
auc_test = roc_auc_score(y_test, y_test_pred_proba)         # AUC en TEST

# %%
print('AUC Train:', round(auc_train,4))
print('AUC Test:', round(auc_test,4))
# Out:
# AUC Train: 0.7196
# AUC Test: 0.6709

# %% [markdown]
# # ROC Curve

# %%
from sklearn.metrics import roc_curve

# %%
# metrics for ROC
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_pred_proba)
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_pred_proba)

# %%
#Plot
plt.figure(figsize=[10,8])
plt.plot(fpr_train, tpr_train, label='TRAIN - AUC: {:.4f}'.format(auc_train))
plt.plot(fpr_test, tpr_test, label='TEST - AUC: {:.4f}'.format(auc_test))
plt.title('ROC Curve')
plt.plot([0,0,1],[0,1,1], color='green', linestyle='--', linewidth=0.5, label='Ideal')
plt.plot([0, 1], [0, 1], color='black', linestyle='--', linewidth=0.5, label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm_test = confusion_matrix(y_test, y_test_pred)

# %%
ConfusionMatrixDisplay(confusion_matrix=cm_test/len(y_test)).plot(colorbar = False, cmap = 'Blues')
plt.title('Confusion Matrix TEST (%)')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('Accuracy:', round( accuracy_score(y_test, y_test_pred),4))
print('Precision:', round( precision_score(y_test, y_test_pred), 4))
print('Recall:', round( recall_score(y_test, y_test_pred), 4))
print('F1-score:', round(f1_score(y_test, y_test_pred), 4))
# Out:
# Accuracy: 0.6235
# Precision: 0.6203
# Recall: 0.6683
# F1-score: 0.6434

# %% [markdown]
# # INTERPRETABILITY

# %% [markdown]
# * Analizamos top features del modelo y su peso en el modelo.
# * Plotear SHAP values y el impacto positivo/negativo.
# * Comentar las top5 features, su impacto en el target y extraer insights.
# * Analisis complementarios:
#   * Modelos de arboles: Feature Importances, plot de arbol de decision.
#   * Modelos lineales: Coeficentes y formula del modelo.

# %%
pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.44.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (535 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.7/535.7 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.2)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.44.1 slicer-0.0.7

# %%
import shap

# %%
#SHAP value: peso en el output final, mantenog todas las vriables estáticas y veo que pasa si aumento las unidades de esa variable.
#Así miramo el impacto que teien sobre el impacto de la previsión. Es una medida del impacto de las variables
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X_test)
plt.title('SHAP values')
shap.summary_plot(shap_values, X_test, plot_type="bar", max_display=60)

# %%
#Salvamos el modelo ganador
modelo_pickle_='/content/drive/MyDrive/Colab Notebooks/TEMPLATE SUP ML (main)/EJERCICIO-ML-SUP/data/modelo_pickle.pkl'
pickle.dump(best_model, open(modelo_pickle_, 'wb'))
