# %% [markdown]
# <a href="https://colab.research.google.com/github/rulogar1234/nuclio-1/blob/master/IMDB_CLASE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Nuclio Digital School - Máster en Data Science**
# ## *Profesora: Raquel Revilla*

# %% [markdown]
# ## **Preprocessing**: Clase 1 - E.D.A. (Exploratory Data Analysis) + Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
imdb = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IMDB_DATOS.csv")

# %%
imdb
# Out:
#      color      director_name  duration        gross  \
# 0    Color    Martin Scorsese       240  116866727.0
# 1    Color        Shane Black       195  408992272.0
# 2   color   Quentin Tarantino       187   54116191.0
# 3    Color   Kenneth Lonergan       186      46495.0
# 4    Color      Peter Jackson       186  258355354.0
# ..     ...                ...       ...          ...
# 92   Color      Steve McQueen       134   56667870.0
# 93   Color   Richard J. Lewis       134    7501404.0
# 94   Color    Paul Greengrass       134  107100855.0
# 95   Color         David Ayer       134   85707116.0
# 96   Color     Clint Eastwood         5   47034272.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# ...

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   color                 86 non-null     object
#  1   director_name         86 non-null     object
#  2   duration              97 non-null     int64
#  3   gross                 89 non-null     float64
#  4   genres                96 non-null     object
#  5   movie_title           97 non-null     object
#  6   title_year            97 non-null     int64
#  7   language              97 non-null     object
#  8   country               97 non-null     object
#  9   budget                93 non-null     float64
#  10  imdb_score            97 non-null     float64
#  11  actors                97 non-null     object
#  12  movie_facebook_likes  97 non-null     int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 10.0+ KB

# %%
#los nulos no los tendrá en cuenta
imdb.describe()
# Out:
#          duration         gross   title_year        budget  imdb_score  \
# count   97.000000  8.900000e+01    97.000000  9.300000e+01   97.000000
# mean   155.515464  1.539379e+08  1975.690722  1.049830e+08    6.871134
# std     73.550452  1.412026e+08   258.477165  7.784829e+07    1.939231
# min    -50.000000  4.122900e+04   202.000000  1.735000e+04   -7.500000
# 25%    138.000000  4.710508e+07  2012.000000  4.000000e+07    6.500000
# 50%    143.000000  1.156040e+08  2013.000000  7.800000e+07    7.200000
# 75%    154.000000  2.410639e+08  2014.000000  1.780000e+08    7.800000
# max    650.000000  6.232795e+08  2016.000000  2.500000e+08    8.800000
#
#        movie_facebook_likes
# count             97.000000
# mean           65273.453608
# std            58018.198425
# min                0.000000
# 25%            24000.000000
# 50%            54000.000000
# 75%            85000.000000
# max           349000.000000

# %%
imdb.shape
# Out:
# (97, 13)

# %%
imdb.head()
# Out:
#     color      director_name  duration        gross  \
# 0   Color    Martin Scorsese       240  116866727.0
# 1   Color        Shane Black       195  408992272.0
# 2  color   Quentin Tarantino       187   54116191.0
# 3   Color   Kenneth Lonergan       186      46495.0
# 4   Color      Peter Jackson       186  258355354.0
#
#                                  genres                          movie_title  \
# 0          Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1               Action|Adventure|Sci-Fi                           Iron Man 3
# 2  Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                 Drama                             Margaret
# 4                     Adventure|Fantasy  The Hobbit: The Desolation of Smaug
#
#    title_year language country       budget  imdb_score  \
# 0        2013  English     USA  100000000.0         8.2
# 1        2013  English     USA  200000000.0         7.2
# ...

# %%
#se puede poner el número de registros, por defecto es 5
imdb.tail(6)
# Out:
#     color     director_name  duration        gross  \
# 91  Color       Tony Gilroy       135  113165635.0
# 92  Color     Steve McQueen       134   56667870.0
# 93  Color  Richard J. Lewis       134    7501404.0
# 94  Color   Paul Greengrass       134  107100855.0
# 95  Color        David Ayer       134   85707116.0
# 96  Color    Clint Eastwood         5   47034272.0
#
#                            genres        movie_title  title_year language  \
# 91      Action|Adventure|Thriller  The Bourne Legacy        2012  English
# 92        Biography|Drama|History   12 Years a Slave        2013  English
# 93                   Comedy|Drama   Barney's Version        2010  English
# 94       Biography|Drama|Thriller   Captain Phillips        2013  English
# 95               Action|Drama|War               Fury        2014  English
# 96  Biography|Drama|Music|Musical        Jersey Boys        2014  English
#
#    country       budget  imdb_score  \
# 91     USA  125000000.0         6.7
# ...

# %% [markdown]
# Quitar duplicados

# %%
#nos devuelve las filas duplicadas
imdb[imdb.duplicated(keep=False)]
# Out:
#     color      director_name  duration        gross  \
# 8   Color        Joss Whedon       173  623279547.0
# 9   Color        Joss Whedon       173  623279547.0
# 19  Color         Tom Hooper       158  148775460.0
# 20  Color         Tom Hooper       158  148775460.0
# 28  Color       Ridley Scott       150   65007045.0
# 29  Color       Ridley Scott       150   65007045.0
# 50  Color         Sam Mendes       143  304360277.0
# 51  Color         Sam Mendes       143  304360277.0
# 52  Color       Baz Luhrmann       143  144812796.0
# 53  Color       Baz Luhrmann       143  144812796.0
# 59  Color  Timur Bekmambetov       141          NaN
# 61  Color  Timur Bekmambetov       141          NaN
#
#                        genres             movie_title  title_year language  \
# 8     Action|Adventure|Sci-Fi            The Avengers        2012  English
# 9     Action|Adventure|Sci-Fi            The Avengers        2012  English
# ...

# %%
#te elimina los primeros
imdb[imdb.duplicated(keep='first')]
# Out:
#     color      director_name  duration        gross  \
# 9   Color        Joss Whedon       173  623279547.0
# 20  Color         Tom Hooper       158  148775460.0
# 29  Color       Ridley Scott       150   65007045.0
# 51  Color         Sam Mendes       143  304360277.0
# 53  Color       Baz Luhrmann       143  144812796.0
# 61  Color  Timur Bekmambetov       141          NaN
#
#                        genres             movie_title  title_year language  \
# 9     Action|Adventure|Sci-Fi            The Avengers        2012  English
# 20      Drama|Musical|Romance          Les Misérables        2012  English
# 29     Action|Adventure|Drama  Exodus: Gods and Kings        2014  English
# 51  Action|Adventure|Thriller                 Skyfall        2012  English
# 53              Drama|Romance        The Great Gatsby        2013  English
# 61    Adventure|Drama|History                 Ben-Hur        2016  English
#
#       country       budget  imdb_score  \
# ...

# %%
#te elimina el último
imdb[imdb.duplicated(keep='last')]
# Out:
#     color      director_name  duration        gross  \
# 8   Color        Joss Whedon       173  623279547.0
# 19  Color         Tom Hooper       158  148775460.0
# 28  Color       Ridley Scott       150   65007045.0
# 50  Color         Sam Mendes       143  304360277.0
# 52  Color       Baz Luhrmann       143  144812796.0
# 59  Color  Timur Bekmambetov       141          NaN
#
#                        genres             movie_title  title_year language  \
# 8     Action|Adventure|Sci-Fi            The Avengers        2012  English
# 19      Drama|Musical|Romance          Les Misérables        2012  English
# 28     Action|Adventure|Drama  Exodus: Gods and Kings        2014  English
# 50  Action|Adventure|Thriller                 Skyfall        2012  English
# 52              Drama|Romance        The Great Gatsby        2013  English
# 59    Adventure|Drama|History                 Ben-Hur        2016  English
#
#       country       budget  imdb_score  \
# ...

# %%
#creamos copia
imdb2 = imdb.copy()

# %%
#inplace nos lo hace sobre el mismo es preferible
#es lo mismo que imdb2 = imdb2.dropcduplicates()
imdb2.drop_duplicates(inplace=True)

# %%
imdb2[imdb2.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [color, director_name, duration, gross, genres, movie_title, title_year, language, country, budget, imdb_score, actors, movie_facebook_likes]
# Index: []

# %%
imdb2.shape
# Out:
# (91, 13)

# %% [markdown]
# tratar nulos

# %%
imdb2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 96
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   color                 80 non-null     object
#  1   director_name         80 non-null     object
#  2   duration              91 non-null     int64
#  3   gross                 84 non-null     float64
#  4   genres                90 non-null     object
#  5   movie_title           91 non-null     object
#  6   title_year            91 non-null     int64
#  7   language              91 non-null     object
#  8   country               91 non-null     object
#  9   budget                87 non-null     float64
#  10  imdb_score            91 non-null     float64
#  11  actors                91 non-null     object
#  12  movie_facebook_likes  91 non-null     int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 10.0+ KB

# %%
#Saber en que columnas hay nulos
imdb2.isnull().any()
# Out:
# color                    True
# director_name            True
# duration                False
# gross                    True
# genres                   True
# movie_title             False
# title_year              False
# language                False
# country                 False
# budget                   True
# imdb_score              False
# actors                  False
# movie_facebook_likes    False
# dtype: bool

# %%
#numero de nulos
imdb2.isnull().sum()
# Out:
# color                   11
# director_name           11
# duration                 0
# gross                    7
# genres                   1
# movie_title              0
# title_year               0
# language                 0
# country                  0
# budget                   4
# imdb_score               0
# actors                   0
# movie_facebook_likes     0
# dtype: int64

# %%
#tratar nulos de la columna color
imdb2['color'].value_counts()
# Out:
# Color               78
# color                1
#  Black and White     1
# Name: color, dtype: int64

# %%
#casi todas son iguales y nonos aporta nada, eliminamos la columna
del(imdb2['color'])

# %%
imdb2.head()
# Out:
#        director_name  duration        gross  \
# 0    Martin Scorsese       240  116866727.0
# 1        Shane Black       195  408992272.0
# 2  Quentin Tarantino       187   54116191.0
# 3   Kenneth Lonergan       186      46495.0
# 4      Peter Jackson       186  258355354.0
#
#                                  genres                          movie_title  \
# 0          Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1               Action|Adventure|Sci-Fi                           Iron Man 3
# 2  Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                 Drama                             Margaret
# 4                     Adventure|Fantasy  The Hobbit: The Desolation of Smaug
#
#    title_year language country       budget  imdb_score  \
# 0        2013  English     USA  100000000.0         8.2
# 1        2013  English     USA  200000000.0         7.2
# 2        2015  English     USA   44000000.0         7.9
# ...

# %%
#miramos el nombre del director
imdb2['director_name'].value_counts()
# Out:
# Michael Bay          3
# Peter Jackson        3
# Christopher Nolan    3
# Ridley Scott         3
# Martin Scorsese      2
#                     ..
# Shane Black          1
# Adam McKay           1
# Zack Snyder          1
# Baz Luhrmann         1
# Clint Eastwood       1
# Name: director_name, Length: 61, dtype: int64

# %%
imdb2[imdb2['director_name'].isnull()]
# Out:
#     color director_name  duration        gross  \
# 5     NaN           NaN       183  330249062.0
# 23  Color           NaN       156  183635922.0
# 30  Color           NaN       150  182204440.0
# 39  Color           NaN       147  407197282.0
# 54    NaN           NaN       143          NaN
# 57  Color           NaN       142  407999255.0
# 69  Color           NaN       139  150832203.0
# 73  Color           NaN       138  150117807.0
# 80  Color           NaN       137   37304950.0
# 82  Color           NaN       137  281666058.0
# 89  Color           NaN       136   52474616.0
#
#                               genres                            movie_title  \
# 5            Action|Adventure|Sci-Fi     Batman v Superman: Dawn of Justice
# 23  Adventure|Drama|Thriller|Western                           The Revenant
# 30       Biography|Drama|History|War                                Lincoln
# 39           Action|Adventure|Sci-Fi             Captain America: Civil War
# ...

# %%
imdb2['director_name'].fillna('sin director',inplace=True)

# %%
imdb2[imdb2['director_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [color, director_name, duration, gross, genres, movie_title, title_year, language, country, budget, imdb_score, actors, movie_facebook_likes]
# Index: []

# %%
#al ser numérico lo podemos graficar para verlo mejor
imdb2.hist('gross')
# Out:
# array([[<Axes: title={'center': 'gross'}>]], dtype=object)

# %%
#Esta opción te sobreimpresiona
imdb2["gross"].hist()
imdb2["budget"].hist()
# Out:
# <Axes: >

# %%
imdb2[imdb2['gross'].isnull()]
# Out:
#     color      director_name  duration  gross  \
# 7   Color        Edward Hall       180    NaN
# 26  Color  Gnana Rajasekaran       153    NaN
# 35  Color          Jay Oliva       148    NaN
# 54    NaN       sin director       143    NaN
# 59  Color  Timur Bekmambetov       141    NaN
# 60  Color  Timur Bekmambetov       141    NaN
# 90  Color   Sadyk Sher-Niyaz       135    NaN
#
#                                     genres  \
# 7                            Drama|Romance
# 26                 Biography|Drama|History
# 35  Action|Animation|Crime|Sci-Fi|Thriller
# 54                   Drama|Horror|Thriller
# 59                 Adventure|Drama|History
# 60                 Adventure|Drama|History
# 90          Action|Biography|Drama|History
#
#                                 movie_title  title_year language     country  \
# 7                                  Restless        2012  English          UK
# 26                                Ramanujan        2014  English       India
# ...

# %%
#Ponemos la mediana en el precio dado que es una campana srewed
imdb2['gross'].fillna(imdb2['gross'].median(), inplace=True)

# %%
imdb2[imdb2['gross'].isnull()]
# Out:
# Empty DataFrame
# Columns: [color, director_name, duration, gross, genres, movie_title, title_year, language, country, budget, imdb_score, actors, movie_facebook_likes]
# Index: []

# %%
imdb2.hist('gross')
# Out:
# array([[<Axes: title={'center': 'gross'}>]], dtype=object)

# %%
#Miramos que valor tenemos
imdb2[imdb2['gross'] >= 6e8]
# Out:
#   director_name  duration        gross                   genres   movie_title  \
# 8   Joss Whedon       173  623279547.0  Action|Adventure|Sci-Fi  The Avengers
#
#    title_year language country       budget  imdb_score  \
# 8        2012  English     USA  220000000.0         8.1
#
#                                               actors  movie_facebook_likes
# 8  Chris Hemsworth,Robert Downey Jr.,Scarlett Joh...                123000

# %%
#value counts se usa más con las VARIABLES CATEGORICAS
imdb2['genres'].value_counts()
# Out:
# Action|Adventure|Sci-Fi                     9
# Drama                                       5
# Crime|Drama|Thriller                        5
# Biography|Drama|History                     4
# Adventure|Fantasy                           3
# Drama|Romance                               3
# Action|Adventure|Thriller                   3
# Action|Adventure|Fantasy                    2
# Crime|Drama|Mystery|Thriller                2
# Action|Adventure|Fantasy|Sci-Fi             2
# Action|Adventure|Sci-Fi|Thriller            2
# Action|Adventure|Drama                      2
# Adventure|Drama|History                     2
# Crime|Drama                                 2
# Drama|History|Thriller                      2
# Biography|Drama|Sport|War                   2
# Adventure|Drama                             1
# Action|Biography|Drama|History              1
# Action|Drama|War                            1
# Action|Crime|Thriller                       1
# ...

# %%
imdb2[imdb2['genres'].isnull()]
# Out:
#           director_name  duration       gross genres movie_title  title_year  \
# 11  Christopher Spencer       170  59696176.0    NaN  Son of God        2014
#
#    language country      budget  imdb_score  \
# 11  English     USA  22000000.0         5.6
#
#                                       actors  movie_facebook_likes
# 11  Roma Downey,Amber Rose Revah,Darwin Shaw                 15000

# %%
#a modo de ejemplo como solo es uno, borramos el registro, borramoa los nulos
imdb2.dropna(subset = ['genres'], inplace = True)

# %%
imdb2[imdb2['genres'].isnull()]
# Out:
# Empty DataFrame
# Columns: [director_name, duration, gross, genres, movie_title, title_year, language, country, budget, imdb_score, actors, movie_facebook_likes]
# Index: []

# %%
#otra manera de hacer el histograma
imdb2['budget'].hist()
# Out:
# <Axes: >

# %%
imdb2[imdb2['budget'].isnull()]
# Out:
#         director_name  duration         gross                   genres  \
# 7         Edward Hall       180  1.477886e+08            Drama|Romance
# 26  Gnana Rajasekaran       153  1.477886e+08  Biography|Drama|History
# 31         Mike Leigh       150  3.958500e+06  Biography|Drama|History
# 93   Richard J. Lewis       134  7.501404e+06             Comedy|Drama
#
#          movie_title  title_year language country  budget  imdb_score  \
# 7           Restless        2012  English      UK     NaN         7.2
# 26         Ramanujan        2014  English   India     NaN         7.0
# 31        Mr. Turner        2014  English      UK     NaN         6.8
# 93  Barney's Version        2010  English  Canada     NaN         7.3
#
#                                            actors  movie_facebook_likes
# 7   Rufus Sewell,Hayley Atwell,Charlotte Rampling                   434
# 26     Mani Bharathi,Michael Lieber,Kevin McGowan                    58
# ...

# %%
#Como la distribución no es normal podenmos la mediana
imdb2['budget'].fillna(imdb2['budget'].median(), inplace=True)

# %%
imdb2[imdb2['budget'].isnull()]
# Out:
# Empty DataFrame
# Columns: [director_name, duration, gross, genres, movie_title, title_year, language, country, budget, imdb_score, actors, movie_facebook_likes]
# Index: []

# %%
imdb2.isnull().any()
# Out:
# director_name           False
# duration                False
# gross                   False
# genres                  False
# movie_title             False
# title_year              False
# language                False
# country                 False
# budget                  False
# imdb_score              False
# actors                  False
# movie_facebook_likes    False
# dtype: bool

# %%
imdb2.isnull().sum()
# Out:
# director_name           0
# duration                0
# gross                   0
# genres                  0
# movie_title             0
# title_year              0
# language                0
# country                 0
# budget                  0
# imdb_score              0
# actors                  0
# movie_facebook_likes    0
# dtype: int64

# %% [markdown]
# **Filtros con condiciones:** Buscar pelis de más de dos horas y con puntuación imdb de más de 7

# %%
imdb2[(imdb2['duration'] > 120) & (imdb2['imdb_score'] > 7)].shape
# Out:
# (49, 12)

# %% [markdown]
# Pelis que se hayan hechp en 2015 o en 2016

# %%
imdb2[(imdb2['title_year'] == 2015) | (imdb2['title_year'] == 2016)]
# Out:
#         director_name  duration         gross  \
# 2   Quentin Tarantino       187  5.411619e+07
# 13       F. Gary Gray       167  1.610293e+08
# 23       sin director       156  1.836359e+08
# 38         Sam Mendes       148  2.000742e+08
# 39       sin director       147  4.071973e+08
# 44        Michael Bay       144  5.282242e+07
# 47       Bryan Singer       144  1.549851e+08
# 55   Steven Spielberg       142  7.230606e+07
# 58        Joss Whedon       141  4.589916e+08
# 59  Timur Bekmambetov       141  1.477886e+08
# 60  Timur Bekmambetov       141  1.477886e+08
# 66          James Wan       140  3.500341e+08
# 70          Gary Ross       139  2.038997e+07
# 82       sin director       137  2.816661e+08
#
#                                   genres  \
# 2   Crime|Drama|Mystery|Thriller|Western
# 13   Biography|Crime|Drama|History|Music
# 23      Adventure|Drama|Thriller|Western
# 38             Action|Adventure|Thriller
# 39               Action|Adventure|Sci-Fi
# ...

# %%
imdb2[(imdb2['title_year'] == 2015) | (imdb2['title_year'] == 2016)].shape
# Out:
# (14, 13)

# %%
#también
imdb2[imdb2['title_year'].isin([2015,2016])].shape
# Out:
# (14, 12)

# %% [markdown]
# Peliculas que esten hechas en UK o en Francia y que además sean de una duración menor de 200 min

# %%
imdb2[imdb2['country'].isin(['UK','France']) & (imdb2['duration'] < 200)]
# Out:
#     color    director_name  duration        gross                     genres  \
# 7   Color      Edward Hall       180  110133245.0              Drama|Romance
# 28  Color     Ridley Scott       150   65007045.0     Action|Adventure|Drama
# 31  Color       Mike Leigh       150    3958500.0    Biography|Drama|History
# 38  Color       Sam Mendes       148  200074175.0  Action|Adventure|Thriller
# 45  Color  Guillaume Canet       144      41229.0       Crime|Drama|Thriller
# 50  Color       Sam Mendes       143  304360277.0  Action|Adventure|Thriller
# 62  Color  Justin Chadwick       141    8324748.0    Biography|Drama|History
# 81    NaN    Walter Salles       137     717753.0            Adventure|Drama
#
#                       movie_title  title_year language country       budget  \
# 7                        Restless        2012  English      UK          NaN
# 28         Exodus: Gods and Kings        2014  English      UK  140000000.0
# ...

# %%
imdb2[imdb2['country'].isin(['UK','France']) & (imdb2['duration'] < 200)].shape
# Out:
# (8, 13)

# %%
imdb2.head()
# Out:
#        director_name  duration        gross  \
# 0    Martin Scorsese       240  116866727.0
# 1        Shane Black       195  408992272.0
# 2  Quentin Tarantino       187   54116191.0
# 3   Kenneth Lonergan       186      46495.0
# 4      Peter Jackson       186  258355354.0
#
#                                  genres                          movie_title  \
# 0          Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1               Action|Adventure|Sci-Fi                           Iron Man 3
# 2  Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                 Drama                             Margaret
# 4                     Adventure|Fantasy  The Hobbit: The Desolation of Smaug
#
#    title_year language country       budget  imdb_score  \
# 0        2013  English     USA  100000000.0         8.2
# 1        2013  English     USA  200000000.0         7.2
# 2        2015  English     USA   44000000.0         7.9
# ...

# %%
#hacemos copia después de la limpieza de nulos, hay outlayers
imdb3 = imdb2.copy()

# %% [markdown]
# **OUTLAYERS** primera forma

# %%
imdb3.hist('duration')
# Out:
# array([[<Axes: title={'center': 'duration'}>]], dtype=object)

# %%
imdb3[imdb3['duration'] < 50]
# Out:
#     color   director_name  duration        gross  \
# 6   Color   Peter Jackson       -50  303001229.0
# 96  Color  Clint Eastwood         5   47034272.0
#
#                            genres                        movie_title  \
# 6               Adventure|Fantasy  The Hobbit: An Unexpected Journey
# 96  Biography|Drama|Music|Musical                        Jersey Boys
#
#     title_year language country       budget  imdb_score  \
# 6         2012  English     USA  180000000.0         7.9
# 96        2014  English     USA   40000000.0         6.9
#
#                                            actors  movie_facebook_likes
# 6           Aidan Turner,Adam Brown,James Nesbitt                166000
# 96  Johnny Cannizzaro,Steve Schirripa,Scott Vance                 16000

# %%
imdb3[imdb3['duration'] > 300]
# Out:
#     color      director_name  duration        gross                    genres  \
# 15  Color  Quentin Tarantino       580  162804648.0             Drama|Western
# 32  Color     Gore Verbinski       650   89289910.0  Action|Adventure|Western
#
#          movie_title  title_year language country       budget  imdb_score  \
# 15  Django Unchained        2012  English     USA  100000000.0         8.5
# 32   The Lone Ranger        2013  English     USA  215000000.0         6.5
#
#                                             actors  movie_facebook_likes
# 15  Leonardo DiCaprio,Christoph Waltz,Ato Essandoh                199000
# 32           Johnny Depp,Ruth Wilson,Tom Wilkinson                 48000

# %%
imdb3.iloc[6,:]
# Out:
# color                                                   Color
# director_name                                   Peter Jackson
# duration                                                  -50
# gross                                             303001229.0
# genres                                      Adventure|Fantasy
# movie_title                 The Hobbit: An Unexpected Journey
# title_year                                               2012
# language                                              English
# country                                                   USA
# budget                                            180000000.0
# imdb_score                                                7.9
# actors                  Aidan Turner,Adam Brown,James Nesbitt
# movie_facebook_likes                                   166000
# Name: 6, dtype: object

# %%
#localizamos los outlayers
imdb3.loc[(imdb3['duration'] < 50) | (imdb3['duration'] > 500), 'duration']
# Out:
# 6     -50
# 15    580
# 32    650
# 96      5
# Name: duration, dtype: int64

# %%
#localizo los que no son outlayers para calcular la media de ellos
imdb3.loc[(imdb3['duration'] >= 50) | (imdb3['duration'] <= 500), 'duration'].mean()
# Out:
# 149.61719599082235

# %%
#esta es la media de los outlayers
imdb3.loc[(imdb3['duration'] < 50) | (imdb3['duration'] > 500), 'duration'] .mean()
# Out:
# 155.7912087912088

# %%
imdb3.loc[(imdb3['duration'] < 50) | (imdb3['duration'] > 500), 'duration'] = imdb3['duration'].mean()

# %%
imdb3.hist('duration')
# Out:
# array([[<Axes: title={'center': 'duration'}>]], dtype=object)

# %% [markdown]
# **OUTLAYERS** segunda forma

# %%
imdb3 = imdb2.copy()

# %%
#el último es donde lo copiamos, EL WHERE NO ACEPTA CONDICIONALES
imdb3['duration'] = np.where(imdb3['duration'] < 50, imdb3['duration'].mean(), imdb3['duration'])

# %%
imdb3.hist('duration')
# Out:
# array([[<Axes: title={'center': 'duration'}>]], dtype=object)

# %%
imdb3['duration'] = np.where(imdb3['duration'] > 300, imdb3['duration'].mean(), imdb3['duration'])

# %%
imdb3.hist('duration')
# Out:
# array([[<Axes: title={'center': 'duration'}>]], dtype=object)

# %%
imdb3 = imdb2.copy()

# %%
imdb3.shape
# Out:
# (90, 12)

# %% [markdown]
# **OUTLAYERS:** borramos los registros

# %%
#localizamos los indices de los outlayers
imdb3[(imdb3['duration'] < 50) | (imdb3['duration'] > 300)].index
# Out:
# Int64Index([6, 15, 32, 96], dtype='int64')

# %%
#Borramos los valores
imdb3.drop(imdb3[(imdb3['duration'] < 50) | (imdb3['duration'] > 300)].index, inplace=True)

# %%
#Verificamos el borrado
imdb3.shape
# Out:
# (86, 12)

# %%
genero_list=imdb3["genres"].str.split('|', expand=True)

# %%
genero_list
# Out:
#             0          1         2         3        4
# 0   Biography     Comedy     Crime     Drama     None
# 1      Action  Adventure    Sci-Fi      None     None
# 2       Crime      Drama   Mystery  Thriller  Western
# 3       Drama       None      None      None     None
# 4   Adventure    Fantasy      None      None     None
# ..        ...        ...       ...       ...      ...
# 91     Action  Adventure  Thriller      None     None
# 92  Biography      Drama   History      None     None
# 93     Comedy      Drama      None      None     None
# 94  Biography      Drama  Thriller      None     None
# 95     Action      Drama       War      None     None
#
# [87 rows x 5 columns]

# %%
genero_list.fillna("sin género", inplace=True)

# %%
genero_list
# Out:
#             0           1           2           3           4
# 0   Biography      Comedy       Crime       Drama  sin género
# 1      Action   Adventure      Sci-Fi  sin género  sin género
# 2       Crime       Drama     Mystery    Thriller     Western
# 3       Drama  sin género  sin género  sin género  sin género
# 4   Adventure     Fantasy  sin género  sin género  sin género
# ..        ...         ...         ...         ...         ...
# 91     Action   Adventure    Thriller  sin género  sin género
# 92  Biography       Drama     History  sin género  sin género
# 93     Comedy       Drama  sin género  sin género  sin género
# 94  Biography       Drama    Thriller  sin género  sin género
# 95     Action       Drama         War  sin género  sin género
#
# [87 rows x 5 columns]

# %%
#creamos las columnas
for i in genero_list:
  imdb3["genero_"+str(i)] = genero_list[i]

# %%
imdb3
# Out:
#      color      director_name  duration        gross  \
# 0    Color    Martin Scorsese       240  116866727.0
# 1    Color        Shane Black       195  408992272.0
# 2   color   Quentin Tarantino       187   54116191.0
# 3    Color   Kenneth Lonergan       186      46495.0
# 4    Color      Peter Jackson       186  258355354.0
# ..     ...                ...       ...          ...
# 91   Color        Tony Gilroy       135  113165635.0
# 92   Color      Steve McQueen       134   56667870.0
# 93   Color   Richard J. Lewis       134    7501404.0
# 94   Color    Paul Greengrass       134  107100855.0
# 95   Color         David Ayer       134   85707116.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# ...
